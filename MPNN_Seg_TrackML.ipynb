# %% [markdown]
# # Message passing neural network segment classifier evaluation
#
# In this notebook we evaluate the results of training a graph network on the TrackML dataset (filtered/cleaned) to classify hit-pair track segments.
#
# The model was trained using the trainSegmentClassifier.py script.

# %% [raw]
# # Device and concurrency settings
# import os
# os.environ['OMP_NUM_THREADS'] = '4'
# os.environ['CUDA_VISIBLE_DEVICES'] = '1'
# cuda = True

# %%
# Compatibility
from __future__ import print_function
from __future__ import division
from __future__ import absolute_import

# %%
# System imports
import os

# %%
# Externals
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# import pandas as pd
# import sklearn.metrics
# from sklearn.model_selection import train_test_split

# %% [raw]
# # Torch imports
# import torch
# from torch.autograd import Variable
# import torch.nn as nn
# import torch.nn.functional as F

# %% [raw]
# # Local imports
# from estimator import Estimator
# from acts import process_hits_files, select_barrel_hits

# %%
# Magics
# %matplotlib notebook

# %% [markdown]
# ## Load the model and data

# %%
train_dir = '/bigdata/shared/HEP.TrkX/GNNSegClf_trkml1GeV_002'

# %%
ls $train_dir
# Out:
# losses.npz  model  out.log

# %%
model_file = os.path.join(train_dir, 'model')
losses_file = os.path.join(train_dir, 'losses.npz')

# %%
losses_data = np.load(losses_file)
train_losses = losses_data['train_losses']
valid_losses = losses_data['valid_losses']

# %%
# Plot the loss
plt.figure()
plt.plot(train_losses, label='training set')
plt.plot(valid_losses, label='validation set')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc=0);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Discussion
#
# Unfortunately I didn't save the test set used for this training run, so there's not too much more I can reliably plot and trust at this stage.
#
# I could just grab some random data for now and look at the accuracy and visualize some samples.
